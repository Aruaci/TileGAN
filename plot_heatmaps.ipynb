# %%
from utils.plot_mask_heatmaps import plot_mask_heatmaps

TEST_DIR = "./tile/test"
CATEGORIES = ["crack", "gray_stroke", "rough", "oil", "glue_strip"]
IMG_SIZE = 128
MASK_DIR = "./tile/ground_truth"

plot_mask_heatmaps(
    categories_to_plot=CATEGORIES,
    image_size=IMG_SIZE,
    mask_base_dir=MASK_DIR,
    test_image_dir=TEST_DIR
)
# Out:
# Searching for masks for category 'crack'...
#   Found 17 masks for 'crack'. Accumulating...
#
# Searching for masks for category 'gray_stroke'...
#   Found 16 masks for 'gray_stroke'. Accumulating...
#
# Searching for masks for category 'rough'...
#   Found 15 masks for 'rough'. Accumulating...
#
# Searching for masks for category 'oil'...
#   Found 18 masks for 'oil'. Accumulating...
#
# Searching for masks for category 'glue_strip'...
#   Found 18 masks for 'glue_strip'. Accumulating...
